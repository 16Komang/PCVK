# %% [markdown]
# <a href="https://colab.research.google.com/github/16Komang/PCVK/blob/main/week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Menghubungkan google colab dan google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Mengimport modul dari phyton
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import math
from google.colab.patches import cv_imshow
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode

# %% [markdown]
# #### Lakukan Face Detection untuk image object lain yang tersedia pada (/images/facedet). Tampilkan seperti pada contoh berikut. Perhatikan pada hasil face detection dibawah ini. Secara keseluruhan, face detection dapat dilakukan dengan baik, bahkan untuk image berupa gambar bukan foto, wajah bermasker, atau wajah yang berukuran kecil (solvay).

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/Images/haarcascades/haarcascade_frontalface_alt.xml')

jokowi = cv.imread('/content/drive/MyDrive/Images/facedet/jokowi.jpg')
jokowi1 = cv.imread('/content/drive/MyDrive/Images/facedet/jokowi.jpg')
roi_wajah1 = cascade_wajah.detectMultiScale(jokowi1) 

roi_wajah = cascade_wajah.detectMultiScale(jokowi) 
for(x,y,w,h) in roi_wajah: 
 cv.rectangle(jokowi,(x,y),(x+w,y+h),(255,0,255),3) 
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(7,5))
plt.subplot(121),plt.imshow(cv.cvtColor(jokowi1, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(jokowi1, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(jokowi, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(jokowi, cv.COLOR_BGR2RGB))
plt.show()

# %%
kartini = cv.imread('/content/drive/MyDrive/Images/facedet/kartini.jpg')
kartini1 = cv.imread('/content/drive/MyDrive/Images/facedet/kartini.jpg')
roi_wajah1 = cascade_wajah.detectMultiScale(kartini1) 

roi_wajah = cascade_wajah.detectMultiScale(kartini) 
for(x,y,w,h) in roi_wajah: 
 cv.rectangle(kartini,(x,y),(x+w,y+h),(255,0,255),3) 
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(7,5))
plt.subplot(121),plt.imshow(cv.cvtColor(kartini1, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(kartini1, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(kartini, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(kartini, cv.COLOR_BGR2RGB))
plt.show()

# %%
kucing = cv.imread('/content/drive/MyDrive/Images/facedet/mycat.jpg')
kucing2 = cv.imread('/content/drive/MyDrive/Images/facedet/mycat.jpg')

kucing_ori = cv.cvtColor(kucing, cv.COLOR_BGR2GRAY)
kucing_kw = cv.cvtColor(kucing2, cv.COLOR_BGR2GRAY)


roi_wajah = cascade_wajah.detectMultiScale(kucing2)
for (x,y,w,h) in roi_wajah: 
  cv.rectangle(kucing2,(x,y),(x+w,y+h),(255,255,255),3) 
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(7,5))
plt.subplot(121),plt.imshow(kucing_ori, cmap='gray')
plt.subplot(122),plt.imshow(kucing_kw, cmap='gray')
plt.show()

# %%
mask = cv.imread('/content/drive/MyDrive/Images/facedet/mask.png',0)
mask1 = cv.imread('/content/drive/MyDrive/Images/facedet/mask.png',0)

roi_wajah = cascade_wajah.detectMultiScale(mask1)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(mask1,(x,y),(x+w,y+h),(255,0,255),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(7,5))
plt.subplot(121),plt.imshow(mask, cmap='gray')
plt.subplot(122),plt.imshow(mask1, cmap='gray')
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x7ff1984c5f00>)

# %%
jordan = cv.imread('/content/drive/MyDrive/Images/facedet/mjordan.jpg',0)
jordan1 = cv.imread('/content/drive/MyDrive/Images/facedet/mjordan.jpg',0)

roi_wajah = cascade_wajah.detectMultiScale(jordan1)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(jordan1,(x,y),(x+w,y+h),(255,0,255),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(7,5))
plt.subplot(121),plt.imshow(jordan, cmap='gray')
plt.subplot(122),plt.imshow(jordan1, cmap='gray')
plt.show()

# %%
kelompok = cv.imread('/content/drive/MyDrive/Images/facedet/solvayconf.jpg',0)
kelompok1 = cv.imread('/content/drive/MyDrive/Images/facedet/solvayconf.jpg',0)

roi_wajah = cascade_wajah.detectMultiScale(kelompok1)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(kelompok1,(x,y),(x+w,y+h),(255,0,255),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(7,5))
plt.subplot(121),plt.imshow(kelompok, cmap='gray')
plt.subplot(122),plt.imshow(kelompok1, cmap='gray')
plt.show()

# %% [markdown]
# #### Pada Soal No.2. wajah kucing tidak bisa dideteksi dengan baik. Lakukan deteksi wajah kucing hingga muncul rectangle pada bagian wajahnya seperti gambar berikut. Petunjuk pada soal ini, perhatikan pretrained features yang telah disediakan OpenCV. Gunakan xml yang ada jika memang telah disediakan. Jika belum ada, coba cari dengan searching melalui search engines.

# %%
cascade_wajah = cv.CascadeClassifier(cv.data.haarcascades + "haarcascade_frontalcatface.xml")

ucing = cv.imread('/content/drive/MyDrive/Images/facedet/mycat.jpg',0)
ucingku = cv.imread('/content/drive/MyDrive/Images/facedet/mycat.jpg',0)

roi_wajah = cascade_wajah.detectMultiScale(ucingku)
for (x,y,w,h) in roi_wajah: 
  cv.rectangle(ucingku,(x,y),(x+w,y+h),(255,255,255),3) 
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(7,5))
plt.subplot(121),plt.imshow(ucing, cmap='gray')
plt.subplot(122),plt.imshow(ucingku, cmap='gray')
plt.show()

# %% [markdown]
# #### Cobakan juga untuk eyes detection pada gambar “Jokowi.jpg”, sehingga menghasilkan gambar seperti berikut.

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/Images/haarcascades/haarcascade_eye.xml')

jokowi = cv.imread('/content/drive/MyDrive/Images/facedet/jokowi.jpg')
jokowi_pro = cv.imread('/content/drive/MyDrive/Images/facedet/jokowi.jpg')
jokowi_gray = cv.cvtColor(jokowi, cv.COLOR_BGR2GRAY)
jokowi_ori_gray = cv.cvtColor(jokowi_pro, cv.COLOR_BGR2GRAY)

roi_wajah = cascade_wajah.detectMultiScale(jokowi_gray)
for (x,y,w,h) in roi_wajah: 
  cv.rectangle(jokowi_gray,(x,y),(x+w,y+h),(255,255,255),3)

f, axarr = plt. subplots(1,2,figsize=(10,5))
plt.subplot(121),plt.imshow(jokowi_ori_gray, cmap='gray')
plt.subplot(122),plt.imshow(jokowi_gray, cmap='gray')
plt.show()

# %% [markdown]
# #### Lakukan Face Tracking menggunakan Google Colab. Petunjuk, Tutorial selengkapnya tentang akses kamera dan FaceDetection pada google colab dapat dilihat di link berikut: https://www.youtube.com/watch?v=YiWh7QvVH60

# %% [markdown]
# #### Lakukan deteksi bagian wajah gambar “mjordan.jpg”, kemudian tindih bagian wajah tersebut dengan gambar “smile.png”. Berikut contoh keluarannya.

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/Images/haarcascades/haarcascade_frontalface_alt.xml')

mjordan_img = cv.imread('/content/drive/MyDrive/Images/facedet/mjordan.jpg')
smile = cv.imread('/content/drive/MyDrive/Images/facedet/smile.png', cv.IMREAD_UNCHANGED)

gray = cv.cvtColor(mjordan_img, cv.COLOR_BGR2GRAY)

faces = cascade_wajah.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

for (x, y, w, h) in faces:
    smile_resized = cv.resize(smile, (w, h))
    mjordan_img[y:y+h, x:x+w] = cv.addWeighted(mjordan_img[y:y+h, x:x+w], 1, smile_resized[:, :, 0:3], 1, 0)

plt.figure(figsize=(7, 5))
plt.subplot(111), plt.imshow(cv.cvtColor(mjordan_img, cv.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# #### Lakukan deteksi wajah dengan menggunakan bounding box berwarna hitam, deteksi mata menggunakan bounding box berwarna putih, dan deteksi mata kanan menggunakan bounding box berwarna merah. Gunakan gambar “people.jpg” untuk mengerjakan soal pada nomor ini. Berikut contoh keluarannya.

# %%
bounding_box = cv.imread('/content/drive/MyDrive/Images/facedet/people.jpg')

gray_image = cv.cvtColor(bounding_box, cv.COLOR_BGR2GRAY)

face_cascade = cv.CascadeClassifier('/content/drive/MyDrive/Images/haarcascades/haarcascade_frontalface_alt.xml')
faces = face_cascade.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=5)

for (x, y, w, h) in faces:
    cv.rectangle(bounding_box, (x, y), (x+w, y+h), (0, 0, 0), 2)

    roi_gray = gray_image[y:y+h, x:x+w]
    eye_cascade = cv.CascadeClassifier('/content/drive/MyDrive/Images/haarcascades/haarcascade_eye.xml')
    eyes = eye_cascade.detectMultiScale(roi_gray, scaleFactor=1.1, minNeighbors=5)

    for (ex, ey, ew, eh) in eyes:
        cv.rectangle(bounding_box, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (0, 0, 255), 2)

        if ex + ew/2 > w/2:
            cv.rectangle(bounding_box, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (255, 255, 255), 2)

plt.figure(figsize=(15, 5))
plt.subplot(111), plt.imshow(cv.cvtColor(bounding_box, cv.COLOR_BGR2RGB))
plt.show()
